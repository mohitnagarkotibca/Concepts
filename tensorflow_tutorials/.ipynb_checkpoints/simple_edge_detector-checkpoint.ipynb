# %%
import os
import tensorflow as tf
import skimage.io as sk

# %%
image = sk.imread('data/plain_cup.png',as_gray=True)

# %%
image.shape
# Out:
# (216, 261)

# %%
plt.imshow(image,cmap='gray')

# %%
kernel_h= np.array([3,3])

# %%
kernel_h
kernel_h=[[1,2,1], [0,0,0], [-1,-2,-1]]

# %%
kernel_v = np.array([3, 3])
kernel_v = [ [1,0,1], [2,0,-2], [-1,0,-1] ]

# %%
input_placeholder = tf.placeholder(

    dtype=tf.float32, shape=(1, image.shape[0], image.shape[1], 1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-f2ba119b50dc> in <module>
# ----> 1 input_placeholder = tf.placeholder(
#         global input_placeholder = undefined
#         global tf.placeholder = undefined
#         global dtype = undefined
#         global tf.float32 = tf.float32
#         global shape = undefined
#         global image.shape = (216, 261)
#       2     dtype=tf.float32, shape=(1, image.shape[0], image.shape[1], 1))
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'
