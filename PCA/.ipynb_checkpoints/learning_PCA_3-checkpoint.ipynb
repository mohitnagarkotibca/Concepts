# %%
import numpy as np
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#Requesting a dataset with 500 examples of 5 features
plt.style.use('fivethirtyeight')
mc= make_blobs(n_samples=500,n_features=5,centers=2,cluster_std=2,random_state=2)
df=pd.DataFrame(mc[0])
df
# Out:
#             0         1         2         3         4
# 0   -2.026780 -7.909183  1.381587 -0.121144 -1.633419
# 1    0.461580 -8.295862 -1.205345 -2.656613 -1.232511
# 2    1.391030 -8.876217  0.084794 -0.264811  0.066273
# 3   -5.684014 -3.178372  3.780967 -4.944419 -4.697998
# 4   -3.319400 -9.496678 -0.874412 -1.643546 -4.466931
# ..        ...       ...       ...       ...       ...
# 495 -5.567769 -3.270397 -0.490350 -3.290516 -4.098224
# 496 -6.502897 -4.619909  2.446091 -5.566436 -4.063107
# 497 -2.830264 -5.625547  2.039533 -3.991660 -7.831654
# 498 -4.374068 -6.658068  1.473618 -2.535465 -4.317003
# 499 -3.036318 -9.794344  1.506390 -3.271110 -2.270288
#
# [500 rows x 5 columns]

# %%
#features
x0=mc[0][:,0]
x1=mc[0][:,1]
x2=mc[0][:,2]
x3=mc[0][:,3]
x4=mc[0][:,4]

#labels
z= mc[1]
plt.scatter(x= x0,y= x1,c=z,edgecolors='black',label='X0')
plt.xlabel('X1')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ## Variance tells us how spread is our data

# %%
df[[0,1]].var()
# Out:
# 0    5.192944
# 1    6.976450
# dtype: float64

# %% [markdown]
# ###  Covariance Matrix tells us Variance in the upper left and lower right cell  , while upper right and lower left tells us the Covariance between the features

# %%
print('Feature 0 has ~5.19 of spread and a negative corelation with feature 1')
df[[0,1]].cov()
# Out:
# feature 0 has ~5.19 of spread and a negative corelation with feature 1
#           0        1
# 0  5.192944 -1.91939
# 1 -1.919390  6.97645

# %%
df.cov()
# Out:
#           0         1         2         3         4
# 0  5.192944 -1.919390 -1.082709  1.674348  1.667914
# 1 -1.919390  6.976450  1.773013 -2.641628 -2.650144
# 2 -1.082709  1.773013  4.826451 -1.354640 -1.120694
# 3  1.674348 -2.641628 -1.354640  5.386333  1.989111
# 4  1.667914 -2.650144 -1.120694  1.989111  6.692115
