# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data= pd.read_csv('data/whreport.csv')

# %%
data.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %% [markdown]
# Variance
#
#
# The average of the squared differences from the Mean.
# ![image.png](attachment:image.png)
#
#
# sum((x-x.mean())**2)/(len(x)-1)
#
# and standard deviation is just square of variance
#
# Key Takeaways.
# - Standard deviation looks at how spread out a group of numbers is from the mean, by looking at the square root of the variance.
#
# - The variance measures the average degree to which each point differs from the mean—the average of all data points.

# %%
# variance
x= data['GDP per capita']
plt.scatter(np.arange(len(data)),data['GDP per capita'])

# %% [markdown]
# Covariance is a statistical tool that is used to determine the relationship between the movement of two features. When two stocks tend to move together, they are seen as having a positive covariance; when they move inversely, the covariance is negative

# %%
data[['Score','GDP per capita']].cov()
# Out:
#                    Score  GDP per capita
# Score           1.239036        0.352052
# GDP per capita  0.352052        0.158714

# %%
data[['Social support','Healthy life expectancy']].cov()
# Out:
#                          Social support  Healthy life expectancy
# Social support                 0.089515                 0.052086
# Healthy life expectancy        0.052086                 0.058624

# %%
data[['Generosity','Social support']].plot()
